# %%
from nltk.corpus import names
import random
import pandas as pd
import numpy as np
import nltk

# %% [markdown]
# # 1. classify a name's gender

# %%
# name is a training database

# %%
labeled_names = ([(name, 'male') for name in names.words('male.txt')] +
[(name, 'female') for name in names.words('female.txt')])

random.shuffle(labeled_names)

# %%
len(labeled_names)
# Out:
# 7944

# %%
#notice puple as element in a list labeled_names
type(labeled_names)
# Out:
# list

# %%
labeled_names
# Out:
# [('Chantal', 'female'),
#  ('Lind', 'female'),
#  ('Christin', 'female'),
#  ('Audrye', 'female'),
#  ('Tracie', 'male'),
#  ('Trista', 'female'),
#  ('Churchill', 'male'),
#  ('Alis', 'female'),
#  ('Hettie', 'female'),
#  ('Antonietta', 'female'),
#  ('Brana', 'female'),
#  ('Dorelle', 'female'),
#  ('Maridel', 'female'),
#  ('Mona', 'female'),
#  ('Joann', 'female'),
#  ('Bobinette', 'female'),
#  ('Curtice', 'male'),
#  ('Stacie', 'female'),
#  ('Tiffany', 'female'),
#  ('Janaya', 'female'),
#  ('Carmen', 'female'),
#  ('Alana', 'female'),
#  ('Jacklyn', 'female'),
#  ('Auberta', 'female'),
#  ('Poul', 'male'),
#  ('Connie', 'female'),
#  ('Tessa', 'female'),
#  ('Samson', 'male'),
#  ('Bea', 'female'),
#  ('Krista', 'female'),
#  ('Skipper', 'male'),
#  ('Gelya', 'female'),
#  ('Vern', 'male'),
#  ('Fidela', 'female'),
#  ('Dorena', 'female'),
#  ('Federico', 'male'),
#  ('Nikita', 'male'),
#  ('Ertha', 'female'),
#  ('Toddie', 'male'),
#  ('Tabby', 'female'),
# ...

# %%
def gender_features(word):
    return {'last_letter': word[-1]}

gender_features('Shrek')
{'last_letter': 'k'}
# Out:
# {'last_letter': 'k'}

# %% [markdown]
# ## nltk.NaiveBayesClassifier deploied

# %%
# notice gender_features() is a function defined

featuresets = [(gender_features(n), gender) for (n, gender) in labeled_names]
train_set, test_set = featuresets[1000:], featuresets[:1000]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
#featuresets

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.783

# %%
classifier.show_most_informative_features(5)
# Out:
# Most Informative Features
#              last_letter = 'a'            female : male   =     35.1 : 1.0
#              last_letter = 'k'              male : female =     31.4 : 1.0
#              last_letter = 'p'              male : female =     17.3 : 1.0
#              last_letter = 'f'              male : female =     15.8 : 1.0
#              last_letter = 'v'              male : female =     10.4 : 1.0

# %%
classifier.classify(gender_features('Neo'))
# Out:
# 'male'

# %%
classifier.classify(gender_features('Trinity'))
# Out:
# 'female'

# %% [markdown]
# ## When working with large corpora, can split the train and test set as follows, to save memories

# %%
from nltk.classify import apply_features
train_set2 = apply_features(gender_features, labeled_names[1000:])
test_set2 = apply_features(gender_features, labeled_names[:1000])

# %% [markdown]
# ## 1.2 Another way to classify name's gender

# %%
def gender_features2(name):
    features = {}
    features["first_letter"] = name[0].lower()
    features["last_letter"] = name[-1].lower()
    for letter in 'abcdefghijklmnopqrstuvwxyz':
        features["count({})".format(letter)] = name.lower().count(letter)
        features["has({})".format(letter)] = (letter in name.lower())
    return features

# %%
# notice count can be used in this way
"classify".count("s")
# Out:
# 2

# %%
#gender_features2('John')

# %%
featuresets2 = [(gender_features2(n), gender) for (n, gender) in labeled_names]
train_set, test_set = featuresets[500:], featuresets[:500]
classifier2 = nltk.NaiveBayesClassifier.train(train_set2)
print(nltk.classify.accuracy(classifier2, test_set2))
# Out:
# 0.753

# %%
featuresets2
# Out:
# [({'first_letter': 'c',
#    'last_letter': 'l',
#    'count(a)': 2,
#    'has(a)': True,
#    'count(b)': 0,
#    'has(b)': False,
#    'count(c)': 1,
#    'has(c)': True,
#    'count(d)': 0,
#    'has(d)': False,
#    'count(e)': 0,
#    'has(e)': False,
#    'count(f)': 0,
#    'has(f)': False,
#    'count(g)': 0,
#    'has(g)': False,
#    'count(h)': 1,
#    'has(h)': True,
#    'count(i)': 0,
#    'has(i)': False,
#    'count(j)': 0,
#    'has(j)': False,
#    'count(k)': 0,
#    'has(k)': False,
#    'count(l)': 1,
#    'has(l)': True,
#    'count(m)': 0,
#    'has(m)': False,
#    'count(n)': 1,
#    'has(n)': True,
#    'count(o)': 0,
#    'has(o)': False,
#    'count(p)': 0,
#    'has(p)': False,
#    'count(q)': 0,
#    'has(q)': False,
#    'count(r)': 0,
#    'has(r)': False,
#    'count(s)': 0,
#    'has(s)': False,
#    'count(t)': 1,
#    'has(t)': True,
#    'count(u)': 0,
#    'has(u)': False,
#    'count(v)': 0,
#    'has(v)': False,
#    'count(w)': 0,
# ...

# %%
# featuresets is a list, each element are tuple of dictionary + gender
type(featuresets2[0])
# Out:
# tuple

# %%
classifier2.classify(gender_features2('Joela'))
# Out:
# 'female'

# %% [markdown]
# ## 1.3 error analysis

# %%
#original divided into 3 groups,train set, test set, and development set
train_names = labeled_names[1500:]
devtest_names = labeled_names[500:1500]
test_names = labeled_names[:500]

# %%
train_set = [(gender_features(n), gender) for (n, gender) in train_names]
devtest_set = [(gender_features(n), gender) for (n, gender) in devtest_names]
test_set = [(gender_features(n), gender) for (n, gender) in test_names]
classifier = nltk.NaiveBayesClassifier.train(train_set) 

print(nltk.classify.accuracy(classifier, devtest_set))
# Out:
# 0.756

# %%
errors = []
for (name, tag) in devtest_names:
    guess = classifier.classify(gender_features(name))
    if guess != tag:
        errors.append( (tag, guess, name) ) #tuple as element appended

# %%
# the inaccurate rate
len(errors)/len(devtest_names)
# Out:
# 0.244

# %%
#errors

# %%
for (tag, guess, name) in sorted(errors):
    print('correct={:<8} guess={:<8s} name={:<30}'.format(tag, guess, name)) #{:<30} is the printing format
# Out:
# correct=female   guess=male     name=Abagael
# correct=female   guess=male     name=Adel
# correct=female   guess=male     name=Adriaens
# correct=female   guess=male     name=Adrian
# correct=female   guess=male     name=Aeriel
# correct=female   guess=male     name=Aigneis
# correct=female   guess=male     name=Alyss
# correct=female   guess=male     name=Amargo
# correct=female   guess=male     name=Ambur
# correct=female   guess=male     name=Ann
# correct=female   guess=male     name=Anne-Mar
# correct=female   guess=male     name=Ardelis
# correct=female   guess=male     name=Ardis
# correct=female   guess=male     name=Bab
# correct=female   guess=male     name=Bel
# correct=female   guess=male     name=Beryl
# correct=female   guess=male     name=Brittan
# correct=female   guess=male     name=Charleen
# correct=female   guess=male     name=Charlot
# correct=female   guess=male     name=Charmian
# correct=female   guess=male     name=Cherlyn
# ...

# %% [markdown]
# ## 1.4 improve features taken

# %%
#take 2 last letters
def gender_features3(word):
    return {'suffix1': word[-1:],
            'suffix2': word[-2:]}

# %%
train_set = [(gender_features3(n), gender) for (n, gender) in train_names]
devtest_set = [(gender_features(n), gender) for (n, gender) in devtest_names]
classifier3 = nltk.NaiveBayesClassifier.train(train_set)

print(nltk.classify.accuracy(classifier3, devtest_set))
# Out:
# 0.609
