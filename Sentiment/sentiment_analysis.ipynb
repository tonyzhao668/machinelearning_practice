# %%
# Load and prepare the dataset
import nltk
from nltk.corpus import movie_reviews
import random

# %%
documents = [(list(movie_reviews.words(fileid)), category)
              for category in movie_reviews.categories()
              for fileid in movie_reviews.fileids(category)]

random.shuffle(documents)

# %%
len(documents)
# Out:
# 2000

# %%
movie_reviews.fileids('pos')
# Out:
# ['pos/cv000_29590.txt',
#  'pos/cv001_18431.txt',
#  'pos/cv002_15918.txt',
#  'pos/cv003_11664.txt',
#  'pos/cv004_11636.txt',
#  'pos/cv005_29443.txt',
#  'pos/cv006_15448.txt',
#  'pos/cv007_4968.txt',
#  'pos/cv008_29435.txt',
#  'pos/cv009_29592.txt',
#  'pos/cv010_29198.txt',
#  'pos/cv011_12166.txt',
#  'pos/cv012_29576.txt',
#  'pos/cv013_10159.txt',
#  'pos/cv014_13924.txt',
#  'pos/cv015_29439.txt',
#  'pos/cv016_4659.txt',
#  'pos/cv017_22464.txt',
#  'pos/cv018_20137.txt',
#  'pos/cv019_14482.txt',
#  'pos/cv020_8825.txt',
#  'pos/cv021_15838.txt',
#  'pos/cv022_12864.txt',
#  'pos/cv023_12672.txt',
#  'pos/cv024_6778.txt',
#  'pos/cv025_3108.txt',
#  'pos/cv026_29325.txt',
#  'pos/cv027_25219.txt',
#  'pos/cv028_26746.txt',
#  'pos/cv029_18643.txt',
#  'pos/cv030_21593.txt',
#  'pos/cv031_18452.txt',
#  'pos/cv032_22550.txt',
#  'pos/cv033_24444.txt',
#  'pos/cv034_29647.txt',
#  'pos/cv035_3954.txt',
#  'pos/cv036_16831.txt',
#  'pos/cv037_18510.txt',
# ...

# %%
type(movie_reviews.words('pos/cv000_29590.txt'))
# Out:
# nltk.corpus.reader.util.StreamBackedCorpusView

# %%
# 'pos/cv000_29590.txt' is one of the fileids
list(movie_reviews.words('pos/cv000_29590.txt'))
# Out:
# ['films',
#  'adapted',
#  'from',
#  'comic',
#  'books',
#  'have',
#  'had',
#  'plenty',
#  'of',
#  'success',
#  ',',
#  'whether',
#  'they',
#  "'",
#  're',
#  'about',
#  'superheroes',
#  '(',
#  'batman',
#  ',',
#  'superman',
#  ',',
#  'spawn',
#  ')',
#  ',',
#  'or',
#  'geared',
#  'toward',
#  'kids',
#  '(',
#  'casper',
#  ')',
#  'or',
#  'the',
#  'arthouse',
#  'crowd',
#  '(',
#  'ghost',
#  'world',
#  ')',
#  ',',
#  'but',
#  'there',
#  "'",
#  's',
#  'never',
#  'really',
#  'been',
#  'a',
#  'comic',
#  'book',
#  'like',
#  'from',
#  'hell',
#  'before',
#  '.',
#  'for',
#  'starters',
#  ',',
#  'it',
#  'was',
#  'created',
#  'by',
#  'alan',
#  'moore',
#  '(',
#  'and',
#  'eddie',
#  'campbell',
#  ')',
#  ',',
#  'who',
#  'brought',
#  'the',
#  'medium',
#  'to',
#  'a',
#  'whole',
#  'new',
#  'level',
#  'in',
#  'the',
#  'mid',
#  "'",
#  '80s',
#  'with',
#  'a',
#  '12',
#  '-',
#  'part',
#  'series',
#  'called',
#  'the',
# ...

# %%
from platform import python_version
print(python_version())
# Out:
# 3.6.13

# %% [markdown]
# ## Split a sentence/text file

# %%
# Python3 program to Convert single
# indexed list into multiple indexed list

# def convert(lst):
#     return (lst[0].split())
 
# # Driver code
# lst =  [str]
# print(convert(lst))
 
def convert(lst):
    return ([i for item in lst for i in item.split()])
     
# Driver code
mystr = "I love you !"
lst =  [mystr]
print(convert(lst))
# Out:
# ['I', 'love', 'you', '!']

# %% [markdown]
# ### Use Regex takes only words ignor other punctuations

# %%
# Python3 code to demonstrate
# to extract words from string
# using regex( findall() )
import re
 
# initializing string 
test_string = "Geeksforgeeks,   is best @# Computer Science Portal.!!!"
 
# printing original string
print ("The original string is : " +  test_string)
 
# using regex( findall() )
# to extract words from string
res = re.findall(r'\w+', test_string)

# printing result
print(res)
# Out:
# The original string is : Geeksforgeeks,   is best @# Computer Science Portal.!!!
# ['Geeksforgeeks', 'is', 'best', 'Computer', 'Science', 'Portal']

# %% [markdown]
# ## Use Naive Bayes classifier to do the Sentiment Analysis

# %%
#print(documents[0])
print(type(documents[0])) #type is tuple structure = (word_list, category)
# Out:
# <class 'tuple'>

# %%
print(type(movie_reviews))
# Out:
# <class 'nltk.corpus.reader.plaintext.CategorizedPlaintextCorpusReader'>

# %%
movie_reviews.categories()
# Out:
# ['neg', 'pos']

# %%
movie_reviews.fileids('pos')[0]
# Out:
# 'pos/cv000_29590.txt'

# %%
movie_reviews.words()
len(movie_reviews.words())
# Out:
# 1583820

# %%
# this all_words are dictionary of {word:frequency}
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())

# word_features are only the list of each unique word/punctuations from list the above dictionary
word_features = list(all_words)[:2000]

# %%
word_features[:10]
# Out:
# [',', 'the', '.', 'a', 'and', 'of', 'to', "'", 'is', 'in']

# %%
len(word_features) # the list with all the unique words
# Out:
# 2000

# %%
print(all_words['the'])
# Out:
# 76529

# %%
def document_features(doc):
    document_words = set(doc)
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words) #if in return "True" otherwise "False".
    return features

# %%
# Train Naive Bayes classifier
featuresets = [(document_features(d), c) for (d,c) in documents]
train_set, test_set = featuresets[400:], featuresets[:400] #80% train 20% test, total 2000
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
type(featuresets)
# Out:
# list

# %%
len(featuresets)
# Out:
# 2000

# %%
featuresets[0]
# Out:
# ({'contains(,)': True,
#   'contains(the)': True,
#   'contains(.)': True,
#   'contains(a)': True,
#   'contains(and)': True,
#   'contains(of)': True,
#   'contains(to)': True,
#   "contains(')": True,
#   'contains(is)': True,
#   'contains(in)': True,
#   'contains(s)': True,
#   'contains(")': True,
#   'contains(it)': True,
#   'contains(that)': True,
#   'contains(-)': True,
#   'contains())': True,
#   'contains(()': True,
#   'contains(as)': True,
#   'contains(with)': True,
#   'contains(for)': True,
#   'contains(his)': True,
#   'contains(this)': True,
#   'contains(film)': True,
#   'contains(i)': True,
#   'contains(he)': False,
#   'contains(but)': True,
#   'contains(on)': True,
#   'contains(are)': True,
#   'contains(t)': True,
#   'contains(by)': True,
#   'contains(be)': True,
#   'contains(one)': True,
#   'contains(movie)': True,
#   'contains(an)': True,
#   'contains(who)': True,
#   'contains(not)': True,
#   'contains(you)': True,
# ...

# %%
type(featuresets[0])
# Out:
# tuple

# %%
# Test the classifier
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.8325

# %%
# Show the most important features as interpreted by Naive Bayes
classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#    contains(outstanding) = True              pos : neg    =      9.0 : 1.0
#    contains(wonderfully) = True              pos : neg    =      8.8 : 1.0
#          contains(mulan) = True              pos : neg    =      8.0 : 1.0
#          contains(damon) = True              pos : neg    =      6.5 : 1.0
#         contains(seagal) = True              neg : pos    =      6.0 : 1.0
#          contains(waste) = True              neg : pos    =      5.9 : 1.0
#          contains(flynt) = True              pos : neg    =      5.4 : 1.0
#          contains(awful) = True              neg : pos    =      5.4 : 1.0
#           contains(lame) = True              neg : pos    =      5.4 : 1.0
#     contains(ridiculous) = True              neg : pos    =      5.1 : 1.0

# %% [markdown]
# ## Split Sentence into {word : frequecy} dictionary

# %%
# notice if not word_tokenized, the output will be in letter not in word 
import nltk
from nltk.probability import FreqDist

sentence='''This is is my sentence'''
tokens = nltk.tokenize.word_tokenize(sentence)
fdist=FreqDist(tokens)

# %%
# Note fdist is a dictionary {word : frequecy}
print(fdist["is"])
# Out:
# 2

# %%
# notice that fdist is a dictionary, list it get the keys list.
words_list = list(fdist)
words_list
# Out:
# ['is', 'This', 'my', 'sentence']

# %% [markdown]
# ## TEST nltk another data base "Brown", however categories>2

# %%
from nltk.corpus import brown
brown.words()
len(brown.words())
# Out:
# 1161192

# %%
#categories > 2
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
#brown.fileids('adventure')

# %%
browndocuments = [(list(brown.words(fileid)), category)
              for category in brown.categories()
              for fileid in brown.fileids(category)]

random.shuffle(browndocuments)

# %%
len(browndocuments)
# Out:
# 500

# %%
#browndocuments[0]

# %%
#list(brown.words('cn01'))

# %%
# after this function, brown_all_words is a dictionary with word:frequency
brown_all_words = nltk.FreqDist(w.lower() for w in brown.words())

# %%
len(brown_all_words)
# Out:
# 49815

# %%
# after this operation, the words feature in a list of 40000 elements
brown_word_features = list(brown_all_words)[:40000]

# %%
brown_featuresets = [(document_features(d), c) for (d,c) in browndocuments]
train_set, test_set = brown_featuresets[100:], brown_featuresets[:100] #80% train 20% test, total 500

# %%
len(brown_featuresets)
# Out:
# 500

# %%
#train classifier
bclassifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
# Test the classifier
print(nltk.classify.accuracy(bclassifier, test_set))
# Out:
# 0.49

# %%
# Show the most important features as interpreted by Naive Bayes
bclassifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#        contains(playing) = True           review : learne =     27.6 : 1.0
#         contains(season) = True           review : learne =     27.6 : 1.0
#        contains(waiting) = True           myster : learne =     27.0 : 1.0
#         contains(caught) = True           advent : learne =     25.9 : 1.0
#           contains(nice) = True            humor : belles =     23.6 : 1.0
#       contains(watching) = True           romanc : learne =     23.3 : 1.0
#         contains(killed) = True           scienc : learne =     22.3 : 1.0
#          contains(naked) = True           scienc : learne =     22.3 : 1.0
#      contains(somewhere) = True           myster : learne =     22.3 : 1.0
#      contains(wonderful) = True            humor : learne =     22.3 : 1.0

# %% [markdown]
# ## use the trained classifier to classify

# %%
testd, testc = test_set[0]

# %%
predicted1 = bclassifier.classify(testd)
predicted1
# Out:
# 'learned'

# %%
testc
# Out:
# 'hobbies'
